# %% [markdown]
# # MLflow Installation on Mac
#
# This notebook covers the complete setup of MLflow on macOS, including installation, configuration, and verification.
#
# ## Prerequisites
# - Python 3.8 or higher
# - pip package manager
# - Homebrew (optional, for advanced setup)

# %% [markdown]
# ## 1. Check Python Version

# %%
import sys
print(f"Python version: {sys.version}")
print(f"Python executable: {sys.executable}")
# Out:
# Python version: 3.13.11 (main, Dec  5 2025, 16:06:33) [Clang 17.0.0 (clang-1700.4.4.1)]
# Python executable: /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/bin/python

# %% [markdown]
# ## 2. Install MLflow
#
# MLflow can be installed using pip. We'll install MLflow with all optional dependencies for GenAI support.

# %%
# Install MLflow with all dependencies
# Note: Quotes are required on zsh (macOS default shell) because brackets are treated as glob patterns
# %pip install "mlflow[genai]" --upgrade
# Out:
# Requirement already satisfied: mlflow[genai] in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (3.8.1)
# Requirement already satisfied: mlflow-skinny==3.8.1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (3.8.1)
# Requirement already satisfied: mlflow-tracing==3.8.1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (3.8.1)
# Requirement already satisfied: Flask-CORS<7 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (6.0.2)
# Requirement already satisfied: Flask<4 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (1.18.2)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (46.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (7.1.0)
# Requirement already satisfied: graphene<4 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (23.0.0)
# Requirement already satisfied: huey<3,>=2.5.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (2.6.0)
# Requirement already satisfied: matplotlib<4 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (3.10.8)
# Requirement already satisfied: numpy<3 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (2.4.1)
# Requirement already satisfied: pandas<3 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (2.2.3)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (19.0.1)
# Requirement already satisfied: scikit-learn<2 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (1.7.2)
# Requirement already satisfied: scipy<2 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (1.16.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (2.0.39)
# Requirement already satisfied: aiohttp<4 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (3.11.14)
# Collecting boto3<2,>=1.28.56 (from mlflow[genai])
#   Downloading boto3-1.42.37-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: fastapi<1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (0.115.12)
# Collecting litellm<2,>=1.0.0 (from mlflow[genai])
#   Downloading litellm-1.81.5-py3-none-any.whl.metadata (30 kB)
# Collecting slowapi<1,>=0.1.9 (from mlflow[genai])
#   Downloading slowapi-0.1.9-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: tiktoken<1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (0.9.0)
# Requirement already satisfied: uvicorn<1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from uvicorn[standard]<1; extra == "genai"->mlflow[genai]) (0.34.0)
# Requirement already satisfied: watchfiles<2 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow[genai]) (1.0.4)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (0.73.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (8.6.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (1.31.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (1.31.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (1.31.1)
# Requirement already satisfied: packaging<26 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (5.29.5)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (1.0.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (0.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from mlflow-skinny==3.8.1->mlflow[genai]) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from aiohttp<4->mlflow[genai]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from aiohttp<4->mlflow[genai]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from aiohttp<4->mlflow[genai]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from aiohttp<4->mlflow[genai]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from aiohttp<4->mlflow[genai]) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from aiohttp<4->mlflow[genai]) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from aiohttp<4->mlflow[genai]) (1.18.3)
# Requirement already satisfied: Mako in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from alembic!=1.10.0,<2->mlflow[genai]) (1.3.10)
# Collecting botocore<1.43.0,>=1.42.37 (from boto3<2,>=1.28.56->mlflow[genai])
#   Downloading botocore-1.42.37-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2,>=1.28.56->mlflow[genai])
#   Using cached jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3<2,>=1.28.56->mlflow[genai])
#   Using cached s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from botocore<1.43.0,>=1.42.37->boto3<2,>=1.28.56->mlflow[genai]) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from botocore<1.43.0,>=1.42.37->boto3<2,>=1.28.56->mlflow[genai]) (2.3.0)
# Requirement already satisfied: cffi>=2.0.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from cryptography<47,>=43.0.0->mlflow[genai]) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow[genai]) (2.48.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from fastapi<1->mlflow[genai]) (0.46.1)
# Requirement already satisfied: blinker>=1.9.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from Flask<4->mlflow[genai]) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from Flask<4->mlflow[genai]) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from Flask<4->mlflow[genai]) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from Flask<4->mlflow[genai]) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from Flask<4->mlflow[genai]) (3.1.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow[genai]) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow[genai]) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow[genai]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow[genai]) (4.9)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from graphene<4->mlflow[genai]) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from graphene<4->mlflow[genai]) (3.2.0)
# Requirement already satisfied: zipp>=3.20 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.8.1->mlflow[genai]) (3.21.0)
# Collecting fastuuid>=0.13.0 (from litellm<2,>=1.0.0->mlflow[genai])
#   Using cached fastuuid-0.14.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (1.1 kB)
# Requirement already satisfied: httpx>=0.23.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from litellm<2,>=1.0.0->mlflow[genai]) (0.28.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.23.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from litellm<2,>=1.0.0->mlflow[genai]) (4.23.0)
# Requirement already satisfied: openai>=2.8.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from litellm<2,>=1.0.0->mlflow[genai]) (2.16.0)
# Requirement already satisfied: tokenizers in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from litellm<2,>=1.0.0->mlflow[genai]) (0.22.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm<2,>=1.0.0->mlflow[genai]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm<2,>=1.0.0->mlflow[genai]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.23.0->litellm<2,>=1.0.0->mlflow[genai]) (0.23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow[genai]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow[genai]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow[genai]) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow[genai]) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow[genai]) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from matplotlib<4->mlflow[genai]) (3.2.5)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==3.8.1->mlflow[genai]) (1.2.18)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.8.1->mlflow[genai]) (0.52b1)
# Requirement already satisfied: pytz>=2020.1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from pandas<3->mlflow[genai]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from pandas<3->mlflow[genai]) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow[genai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow[genai]) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow[genai]) (0.4.2)
# Requirement already satisfied: six>=1.5 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.37->boto3<2,>=1.28.56->mlflow[genai]) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow[genai]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow[genai]) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow[genai]) (2025.1.31)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow[genai]) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from scikit-learn<2->mlflow[genai]) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from scikit-learn<2->mlflow[genai]) (3.6.0)
# Collecting limits>=2.3 (from slowapi<1,>=0.1.9->mlflow[genai])
#   Downloading limits-5.6.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow[genai]) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow[genai]) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from tiktoken<1->mlflow[genai]) (2024.11.6)
# Requirement already satisfied: h11>=0.8 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from uvicorn<1->uvicorn[standard]<1; extra == "genai"->mlflow[genai]) (0.14.0)
# Requirement already satisfied: httptools>=0.6.3 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from uvicorn[standard]<1; extra == "genai"->mlflow[genai]) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from uvicorn[standard]<1; extra == "genai"->mlflow[genai]) (0.22.1)
# Requirement already satisfied: websockets>=10.4 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from uvicorn[standard]<1; extra == "genai"->mlflow[genai]) (15.0.1)
# Requirement already satisfied: pycparser in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow[genai]) (2.23)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==3.8.1->mlflow[genai]) (1.17.2)
# Requirement already satisfied: httpcore==1.* in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from httpx>=0.23.0->litellm<2,>=1.0.0->mlflow[genai]) (1.0.7)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from openai>=2.8.0->litellm<2,>=1.0.0->mlflow[genai]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from openai>=2.8.0->litellm<2,>=1.0.0->mlflow[genai]) (0.12.0)
# Requirement already satisfied: tqdm>4 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from openai>=2.8.0->litellm<2,>=1.0.0->mlflow[genai]) (4.67.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from tokenizers->litellm<2,>=1.0.0->mlflow[genai]) (0.36.0)
# Requirement already satisfied: filelock in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<2,>=1.0.0->mlflow[genai]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<2,>=1.0.0->mlflow[genai]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm<2,>=1.0.0->mlflow[genai]) (1.2.0)
# Downloading boto3-1.42.37-py3-none-any.whl (140 kB)
# Downloading botocore-1.42.37-py3-none-any.whl (14.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 29.6 MB/s  0:00:00eta 0:00:01
# Using cached jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading litellm-1.81.5-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 48.6 MB/s  0:00:00 eta 0:00:01
# Using cached s3transfer-0.16.0-py3-none-any.whl (86 kB)
# Downloading slowapi-0.1.9-py3-none-any.whl (14 kB)
# Using cached fastuuid-0.14.0-cp313-cp313-macosx_11_0_arm64.whl (251 kB)
# Downloading limits-5.6.0-py3-none-any.whl (60 kB)
# Installing collected packages: jmespath, fastuuid, limits, botocore, slowapi, s3transfer, litellm, boto3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [boto3]32m7/8 [boto3]m]]
# Successfully installed boto3-1.42.37 botocore-1.42.37 fastuuid-0.14.0 jmespath-1.1.0 limits-5.6.0 litellm-1.81.5 s3transfer-0.16.0 slowapi-0.1.9
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 3. Install Additional Dependencies
#
# For working with ResponseAgent and LangGraph, we need additional packages.

# %%
# # Install core dependencies for ResponseAgent
# !pip install pydantic>=2.0.0
# !pip install openai

# # Install LangGraph and LangChain for agent development
# !pip install langgraph>=0.2.27
# !pip install langchain>=0.3.0
# !pip install langchain-openai>=0.2.0

# # Install additional utilities
# !pip install backoff
# !pip install python-dotenv

# %% [markdown]
# ## 4. Verify MLflow Installation

# %%
from importlib.metadata import version, PackageNotFoundError

import mlflow
print(f"MLflow version: {mlflow.__version__}")

# Verify Pydantic version (must be >= 2.0 for ResponseAgent)
import pydantic
print(f"Pydantic version: {pydantic.__version__}")

# Verify LangGraph (doesn't have __version__ attribute, so use importlib.metadata)
try:
    import langgraph
    print(f"LangGraph version: {version('langgraph')}")
except (ImportError, PackageNotFoundError):
    print("LangGraph not installed")
# Out:
# MLflow version: 3.8.1
# Pydantic version: 2.12.5
# LangGraph version: 1.0.7

# %% [markdown]
# ## 5. Setup MLflow Tracking Server (Local)
#
# MLflow uses a tracking server to log experiments, models, and artifacts. For local development, we can use a file-based backend.

# %%
import os
from pathlib import Path

# Create MLflow directories
mlflow_dir = Path.home() / "mlflow_experiments"
mlflow_dir.mkdir(exist_ok=True)

# Set tracking URI to local directory
mlflow.set_tracking_uri(f"file://{mlflow_dir}")
print(f"MLflow tracking URI: {mlflow.get_tracking_uri()}")
# Out:
# MLflow tracking URI: file:///Users/sourav.banerjee/mlflow_experiments

# %% [markdown]
# ## 6. Start MLflow UI Server
#
# To view experiments in a web interface, start the MLflow UI server.
#
# **Run this command in a separate terminal:**
#
# ```bash
# mlflow ui --backend-store-uri file:///Users/sourav.banerjee/mlflow_experiments
# ```
#
# Then open http://localhost:5000 in your browser.

# %% [markdown]
# ## 7. Setup Environment Variables
#
# Create a `.env` file for API keys and configuration.

# %%
# # Create .env file template
# env_template = """
# # OpenAI API Key (required for examples)
# OPENAI_API_KEY=your_openai_api_key_here

# # MLflow Configuration
# MLFLOW_TRACKING_URI=file://~/mlflow_experiments
# MLFLOW_EXPERIMENT_NAME=default
# """

# with open(".env", "w") as f:
#     f.write(env_template.strip())

# print("Created .env file. Please update with your API keys.")

# %% [markdown]
# ## 8. Test Basic MLflow Functionality

# %%
# Create a test experiment
experiment_name = "test_installation"
mlflow.set_experiment(experiment_name)

# Log a simple run
with mlflow.start_run():
    mlflow.log_param("test_param", "value")
    mlflow.log_metric("test_metric", 1.0)
    print("✅ Successfully logged test run to MLflow")

print(f"\n✅ Installation complete! View experiments at: {mlflow.get_tracking_uri()}")
# Out:
# /Users/sourav.banerjee/Documents/Codebases/2. AI ENGINEERING/LangChain_Demystified/.venv/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/utils.py:178: FutureWarning: The filesystem tracking backend (e.g., './mlruns') will be deprecated in February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://github.com/mlflow/mlflow/issues/18534 for more details and migration guidance. For migrating existing data, https://github.com/mlflow/mlflow-export-import can be used.
#   return FileStore(store_uri, store_uri)
# 2026/01/29 10:05:22 INFO mlflow.tracking.fluent: Experiment with name 'test_installation' does not exist. Creating a new experiment.
# ✅ Successfully logged test run to MLflow
#
# ✅ Installation complete! View experiments at: file:///Users/sourav.banerjee/mlflow_experiments

# %% [markdown]
# ## 9. Installation Summary
#
# ### ✅ What We Installed:
# 1. **MLflow** - Core platform for ML lifecycle management
# 2. **Pydantic v2+** - Required for ResponseAgent
# 3. **LangGraph** - For building stateful AI agents
# 4. **LangChain** - Integration with LangGraph
# 5. **OpenAI** - For LLM integration
#
# ### 🚀 Next Steps:
# 1. Add your OpenAI API key to `.env` file
# 2. Start MLflow UI: `mlflow ui`
# 3. Move to the next notebook to learn about ResponseAgent
#
# ### 📚 Useful Commands:
# ```bash
# # Start MLflow UI
# mlflow ui
#
# # Start with custom port
# mlflow ui --port 8080
#
# # Check MLflow version
# mlflow --version
#
# # View all MLflow commands
# mlflow --help
# ```
